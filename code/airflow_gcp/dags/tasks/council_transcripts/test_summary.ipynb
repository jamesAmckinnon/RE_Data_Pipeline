# %%
 "Combine the following city council transcript snippets into a single coherent markdown report. Extract"
                "important information that could impact the commercial real estate industry, including zoning"
                "and bylaw changes, carried bylaw motions, property tax discussions, general discussion about real estate, or topics"
                "relevant to real estate investors, brokers or developers, etc. Make the report as concise as"
                "possible while using as many facts from the text as you can. Focus on changes that are happening"
                "and any arguments for or against these changes. For zoning changes, focus more on summarizing reasoning"
                "for why the change is supported or not supported and only provide basic information about the zones themselves."
                "Only use information discussed in the text and do not add any of your own opinions or interpretations of the information."
                "IMPORTANT: Include inline hyperlinked source citations (Eg. [[1]](the YouTube Link) at the end of the lines or paragraphs where the snippet's information was used."
                "\n\n{text}\n\nFinal Summary:"

# %% [markdown]
# # City Council Report on Recent Zoning and Real Estate-Related Decisions
# This report summarizes key discussions and decisions from the recent city council meeting relevant to the commercial real estate industry, including zoning amendments, bylaw motions, property tax considerations, and infrastructure impacts affecting developers, investors, and brokers.
# ---
# ## 1. Schonsee Neighbourhood Rezoning and Development
# - **Location & Context:** The site is located west of 66 Street and north of 167 Avenue, adjacent to a natural wetland with multi-use trails, residential and commercial developments, and vacant land zoned for neighbourhood commercial use. Transit service is available at 66 Street and 167 Avenue, with shared pathways and park spaces nearby [[2:38:40]](https://www.youtube.com/watch?v=775c_Ae9XYY&t=9520s).
# - **Proposed Zoning Changes:**
#   - Allow a mix of small-scale residential (up to 3 storeys, RSF zone), medium-scale housing (4 to 6 storeys, RMH 16 and H 23 zones), and neighbourhood-scale mixed-use development (up to 4 storeys, MUN zone).
#   - Conservation and restoration of natural areas (NA zone) to protect wetlands and provide passive recreational opportunities.
#   - Amendments to the Edmonton North Area Structure Plan and Schonsee Neighbourhood Structure Plan to reflect added commercial uses, adjusted residential densities, park space, pedestrian connections, and boundary realignments including Crystalina Nera Drive and future 170th Avenue [[2:38:40]](https://www.youtube.com/watch?v=775c_Ae9XYY&t=9520s).
# - **Density Impact:** The rezoning results in a minor increase in residential density from 39 to 40 dwelling units per net residential hectare, equating to approximately 11 additional units. This increase involves a small land area shift to medium density from other land uses [[2:44:51]](https://www.youtube.com/watch?v=775c_Ae9XYY&t=9891s), [[2:51:11]](https://www.youtube.com/watch?v=775c_Ae9XYY&t=10271s).
# - **Support and Concerns:**
#   - Administration recommends support, citing alignment with the City Plan goals to foster local living, growth in established neighbourhoods, and better housing and commercial mix.
#   - Conservation of wetlands and provision of recreational opportunities are highlighted as benefits.
#   - Some councillors and residents expressed concerns about incremental density increases and traffic congestion, particularly at 66 Street and 167 Avenue, which is currently a bottleneck. Road upgrades including a traffic circle and twinning of roads are underway or planned, with phased construction expected through 2026-2027 [[2:44:51]](https://www.youtube.com/watch?v=775c_Ae9XYY&t=9891s), [[2:54:19]](https://www.youtube.com/watch?v=775c_Ae9XYY&t=10459s).
#   - Administration confirmed coordination with developers and the city to improve communication with residents, including potential use of QR codes and technology to better inform the public about construction and planning [[2:57:29]](https://www.youtube.com/watch?v=775c_Ae9XYY&t=10649s).
# - **Building Height and Housing Variety:**
#   - The RMH 23 zone allows up to 6 storeys; RMH 16 allows medium density with different housing styles such as townhouses.
#   - Administration prefers RMH 23 along arterial roads to maximize housing variety and density, with no current plans to reduce height to RMH 16 despite resident concerns [[2:38:40]](https://www.youtube.com/watch?v=775c_Ae9XYY&t=9520s), [[2:44:51]](https://www.youtube.com/watch?v=775c_Ae9XYY&t=9891s).
# - **Council Decision:** The rezoning and associated bylaws were carried unanimously after debate, with councillors noting the importance of context and the need to address problem properties through redevelopment [[3:32:39]](https://www.youtube.com/watch?v=775c_Ae9XYY&t=12759s).
# ---
# ## 2. Direct Control Rezoning for Supportive Housing and Emergency Shelter Uses
# - **Background:** A direct control zoning application was discussed to remove a sunset clause on emergency shelter use, effectively making the use permanent. The original sunset clause was intended to encourage development and avoid stagnation but was removed to support a unique model of integrated health and shelter services [[1:13:41]](https://www.youtube.com/watch?v=775c_Ae9XYY&t=4421s).
# - **Use Classification and Policy:**
#   - The zoning allows for emergency shelter, transitional housing, supportive housing, and health services on site.
#   - The city does not consider the demographics of users in land use decisions but focuses on impacts to the neighbourhood.
#   - There is no specific city policy directing decentralization of social services; rather, the City Plan supports distributing core housing amenities city-wide [[1:13:41]](https://www.youtube.com/watch?v=775c_Ae9XYY&t=4421s).
# - **Sunset Clause Use:**
#   - Sunset clauses are typically used to incentivize development by limiting the time a zoning use is valid if development does not proceed.
#   - They are not commonly used for permanent infrastructure or social service uses, except for temporary uses like parking lots [[1:13:41]](https://www.youtube.com/watch?v=775c_Ae9XYY&t=4421s).
# - **Community Concerns and Operational Issues:**
#   - Concerns were raised about crime, litter, noise, and disorder associated with shelter sites.
#   - Enforcement of shelter standards is limited as these are provincial matters; the city can only address community standards and bylaw enforcement.
#   - The applicant (a non-profit) highlighted the significant administrative and financial burden of rezoning applications, especially when required to reapply due to sunset clauses [[1:22:52]](https://www.youtube.com/watch?v=775c_Ae9XYY&t=4972s).
# - **Council Discussion:**
#   - Some councillors expressed support for making the use permanent to avoid repeated rezoning costs and to support integrated health and shelter models.
#   - Others reflected on the need for ongoing advocacy with provincial authorities regarding shelter operations and standards [[1:19:54]](https://www.youtube.com/watch?v=775c_Ae9XYY&t=4794s).
# ---
# ## 3. Alley and Infrastructure Considerations in Residential Developments
# - **Rear Alley Access:**
#   - A discussion on a residential rezoning noted that rear alleys in the area are underutilized and unpaved.
#   - The city is considering repurposing some alleys for green infrastructure or other uses as part of the alley renewal program.
#   - Waste collection in the neighbourhood is primarily from street access rather than alleys, consistent with the original neighbourhood design [[3:16:57]](https://www.youtube.com/watch?v=775c_Ae9XYY&t=11817s).
# - **Built Form and Access:**
#   - Some developments include direct control zoning with restrictions on built form to address community concerns, such as enhanced front yards, narrow driveways, and landscaping.
#   - Access from alleys is preferred where practical, but exceptions are made based on site conditions [[3:13:44]](https://www.youtube.com/watch?v=775c_Ae9XYY&t=11624s).
# ---
# ## 4. Procedural Notes and Council Motions
# - Several bylaw motions related to the above rezonings were carried, mostly unanimously, with some minor opposition noted on procedural items [[2:34:41]](https://www.youtube.com/watch?v=775c_Ae9XYY&t=9281s), [[3:32:39]](https://www.youtube.com/watch?v=775c_Ae9XYY&t=12759s).
# - Items not dealt with during the meeting were postponed to the next scheduled meeting on August 18th [[3:33:52]](https://www.youtube.com/watch?v=775c_Ae9XYY&t=12832s).
# ---
# # Summary
# The council approved rezonings that support increased residential density and mixed-use development in the Schonsee neighbourhood, with minor density increases and infrastructure upgrades planned to address traffic concerns. Conservation of natural wetlands and provision of recreational spaces are integrated into the plans. The council also moved to make permanent certain emergency shelter uses by removing sunset clauses, balancing community concerns with the need for supportive housing. Infrastructure discussions highlighted opportunities to repurpose underutilized alleys and improve communication with residents regarding development impacts. These decisions reflect ongoing efforts to balance growth, community safety, and housing needs in Edmonton.
# ---
# *Sources:*
# - [[2:38:40]](https://www.youtube.com/watch?v=775c_Ae9XYY&t=9520s) Schonsee Neighbourhood Rezoning Presentation
# - [[2:34:41]](https://www.youtube.com/watch?v=775c_Ae9XYY&t=9281s) Council Debate and Vote on Rezoning Items
# - [[2:44:51]](https://www.youtube.com/watch?v=775c_Ae9XYY&t=9891s) Density and Infrastructure Questions
# - [[2:54:19]](https://www.youtube.com/watch?v=775c_Ae9XYY&t=10459s) Road Upgrades and Developer Coordination
# - [[2:57:29]](https://www.youtube.com/watch?v=775c_Ae9XYY&t=10649s) Communication Improvements with Residents
# - [[3:32:39]](https://www.youtube.com/watch?v=775c_Ae9XYY&t=12759s) Final Votes and Council Comments
# - [[1:13:41]](https://www.youtube.com/watch?v=775c_Ae9XYY&t=4421s) Direct Control Zoning and Shelter Use Discussion
# - [[1:19:54]](https://www.youtube.com/watch?v=775c_Ae9XYY&t=4794s) Shelter Operations and Legal Considerations
# - [[3:16:57]](https://www.youtube.com/watch?v=775c_Ae9XYY&t=11817s) Alley Use and Built Form Considerations

# %% [markdown]
# # City Council Report Summary: Implications for Commercial Real Estate Industry
# This report consolidates key discussions and decisions from the recent Edmonton City Council meeting relevant to commercial real estate investors, brokers, developers, and related stakeholders. It focuses on zoning and bylaw changes, property tax discussions, capital budget adjustments, infrastructure renewal, and growth-related infrastructure priorities.
# ---
# ## 1. Bylaw Amendments and Infrastructure Projects
# - **Bylaw 21063 Amendment**: Council approved an amendment to Bylaw 20392 concerning the City of Edmonton Integrated Infrastructure Services project, specifically for climate resilience facility upgrades at the An Mithrie site. This bylaw was carried without debate [[0:34:20]](https://www.youtube.com/watch?v=kEGYjFjDmBQ&t=2060s).
# - **Supplemental Capital Budget Adjustments (2023-2026)**: A $75 million net increase was approved to the capital budget, representing about 0.7% of the $11 billion approved budget. Adjustments include:
#   - Funding for neighbourhood renewal projects extending into 2027 and beyond.
#   - Safety and security enhancements.
#   - Renovations to public recreation, cultural facilities, and city-owned buildings.
#   - Offsets include federal funding for housing projects in Garneau and cancellation of some projects like the e-park machine upgrades and Indigenous cultural centre [[1:10:17]](https://www.youtube.com/watch?v=kEGYjFjDmBQ&t=4217s).
# - **Emerging Projects Flagged**: These include base-level development for school sites, Windemere district park construction, Rossdale power plant roof replacement, and several transit projects. Tariffs between Canada and the U.S. may impact capital programs [[1:10:17]](https://www.youtube.com/watch?v=kEGYjFjDmBQ&t=4217s).
# ---
# ## 2. Infrastructure Renewal and Funding Gap
# - **Significant Renewal Funding Gap**: The city faces a projected $1.6 billion shortfall in renewal funding for 2027-2030, with an estimated $4.4 billion renewal requirement but only $2.8 billion forecasted funding. Underfunding renewal risks increased liabilities, service declines, higher operating costs, and future funding pressures [[2:31:48]](https://www.youtube.com/watch?v=kEGYjFjDmBQ&t=9108s).
# - **Renewal Deficit Concerns**: Council members expressed concern over a "perpetual renewal deficit" affecting city assets valued at $34 billion. Disposition of assets is ongoing but will not significantly reduce the deficit in the short term. Rationalization efforts include reviewing city-owned non-core facilities such as fire stations, police stations, and aquatic centres [[2:35:20]](https://www.youtube.com/watch?v=kEGYjFjDmBQ&t=9320s), [[6:01:54]](https://www.youtube.com/watch?v=kEGYjFjDmBQ&t=21714s).
# - **Property Taxes as Primary Funding Source**: Due to limited provincial and federal unconstrained funding, property taxes remain the main tool to address renewal funding gaps. User fees may contribute to operational costs but are less applicable to capital renewal [[5:33:36]](https://www.youtube.com/watch?v=kEGYjFjDmBQ&t=20016s).
# - **Calls for Dedicated Renewal Funding**: Some councillors advocated for a dedicated renewal fund supported by incremental property tax increases starting in 2026 to address the funding gap systematically [[5:52:40]](https://www.youtube.com/watch?v=kEGYjFjDmBQ&t=21160s).
# ---
# ## 3. Growth-Related Infrastructure and Capital Prioritization
# - **Arterial Roads and Mobility Infrastructure**: Growth pressures, especially population increases over the last 3-4 years, have intensified demands on arterial roads and mobility infrastructure. Key arterial road priorities identified in previous reports include 167th Avenue and 66th Street, Parsons Road at Ellerslie, and 215 Street. However, councillors noted that growth has outpaced funding and analysis, calling for updated assessments and prioritization citywide [[6:05:16]](https://www.youtube.com/watch?v=kEGYjFjDmBQ&t=21916s), [[1:22:41]](https://www.youtube.com/watch?v=kEGYjFjDmBQ&t=4961s).
# - **Emerging Items and Grant Opportunities**: Some growth-related projects, such as transit initiatives, are prioritized due to available grant funding. However, growth projects generally compete with renewal projects for limited capital funds, with safety-related projects receiving precedence in interim budget adjustments [[1:38:48]](https://www.youtube.com/watch?v=kEGYjFjDmBQ&t=5928s).
# - **Motion for Mobility Infrastructure Update**: Council approved a motion directing administration to provide an update on mobility infrastructure prioritization, including arterial roads, reflecting changed conditions such as growth, cost escalation, and tariffs, with a report due in Q1 2026 [[6:05:16]](https://www.youtube.com/watch?v=kEGYjFjDmBQ&t=21916s).
# ---
# ## 4. Neighbourhood Renewal and Project Scope
# - **Neighbourhood and Alley Renewal Program**: An $86.5 million budget was approved for neighbourhood and alley renewal projects. Council discussed concerns about varying project scopes and costs across neighbourhoods (e.g., Castle Downs vs. Lessard). Planning and design phases are mostly complete, and the current budget covers construction costs. Delaying approval could postpone entire neighbourhood renewal timelines [[1:13:18]](https://www.youtube.com/watch?v=kEGYjFjDmBQ&t=4398s), [[1:10:17]](https://www.youtube.com/watch?v=kEGYjFjDmBQ&t=4217s).
# - **Infrastructure Committee Review**: Council may request detailed reviews of project scopes and costs through the Infrastructure Committee, but such reviews could impact project timing [[1:13:18]](https://www.youtube.com/watch?v=kEGYjFjDmBQ&t=4398s).
# ---
# ## 5. Specific Infrastructure Projects and Conditions
# - **Trestle Bridge and Culvert Replacement**: The trestle bridge has reached end-of-life with erosion damage. Replacement includes ecological restoration by daylighting Mill Creek and improving bank stability [[1:35:32]](https://www.youtube.com/watch?v=kEGYjFjDmBQ&t=5732s).
# - **Sidewalks and Road Conditions**: Councillors noted deteriorating sidewalks, curbs, drainage, and pervasive potholes, emphasizing the need for timely renewal to avoid escalating maintenance costs [[1:19:39]](https://www.youtube.com/watch?v=kEGYjFjDmBQ&t=4779s).
# - **Rossdale Power Plant Roof Replacement**: Repairs focus on emergency rehabilitation to maintain future redevelopment options. Further upgrades will be considered once reuse plans are finalized [[1:29:15]](https://www.youtube.com/watch?v=kEGYjFjDmBQ&t=5355s).
# - **School Site Infrastructure**: Infrastructure investments for new schools are mandated under joint use agreements. Administration is exploring provincial funding opportunities, including the School Accelerator Program, to offset city costs [[1:29:15]](https://www.youtube.com/watch?v=kEGYjFjDmBQ&t=5355s).
# ---
# ## 6. Property Tax and Funding Discussions
# - **Property Tax Debates Postponed**: A motion related to property tax adjustments was postponed due to the absence of a key councillor, with plans to revisit the discussion later [[0:34:20]](https://www.youtube.com/watch?v=kEGYjFjDmBQ&t=2060s).
# - **Advocacy for Balanced Approach**: Council members emphasized the need to balance growth and renewal funding, cautioning against diverting tax uplift from infill and industrial development to other uses, stressing the importance of focusing on renewal [[6:01:54]](https://www.youtube.com/watch?v=kEGYjFjDmBQ&t=21714s).
# ---
# ## 7. Public Engagement and Budget Transparency
# - **Public Engagement in Budgeting**: The city conducts robust public engagement during the four-year budget cycle, including focus groups and community events, to capture diverse stakeholder input. This engagement informs service prioritization and budget decisions [[4:48:38]](https://www.youtube.com/watch?v=kEGYjFjDmBQ&t=17318s).
# - **Transparency on Neighbourhood Renewal Plans**: Annual updates on neighbourhood renewal projects, including phasing and scope, are provided to council and can be made accessible to the public upon request [[1:22:41]](https://www.youtube.com/watch?v=kEGYjFjDmBQ&t=4961s).
# ---
# # Summary
# The City of Edmonton is actively managing a complex balance between infrastructure renewal and growth-related capital needs amid constrained funding. The commercial real estate sector should note:
# - Continued investment in infrastructure renewal is critical but underfunded, with property taxes as the primary funding source.
# - Growth pressures, especially on arterial roads and mobility infrastructure, are increasing and will be reassessed for prioritization.
# - Neighbourhood renewal projects are advancing with significant budgets, though scope and cost scrutiny remain ongoing.
# - Specific infrastructure projects, including bridges, sidewalks, and school-related amenities, are prioritized for safety and compliance.
# - Opportunities for provincial and federal grant funding exist but are limited and often tied to growth projects.
# - Public engagement and transparency efforts continue to shape budget priorities and project scopes.
# Stakeholders should monitor upcoming budget cycles, mobility infrastructure reports (due Q1 2026), and potential property tax policy changes that may impact development costs and investment returns.
# ---
# *All information is sourced directly from the Edmonton City Council meeting transcript and related discussions [[0:34:20]](https://www.youtube.com/watch?v=kEGYjFjDmBQ&t=2060s) through [[4:48:38]](https://www.youtube.com/watch?v=kEGYjFjDmBQ&t=17318s).*

# %%
"Combine the following city council transcript snippets into a single coherent markdown report. Extract"
                "important information that could impact the commercial real estate industry, including zoning"
                "and bylaw changes, carried bylaw motions, property tax discussions, general discussion about real estate, or topics"
                "relevant to real estate investors, brokers or developers, etc. Make the report as concise as"
                "possible while using as many facts from the text as you can. Focus on changes that are happening"
                "and any arguments for or against these changes. For zoning changes, focus more on summarizing reasoning"
                "for why the change is supported or not supported and only provide basic information about the zones themselves."
                "Only use information discussed in the text and do not add any of your own opinions or interpretations of the information."
                "IMPORTANT: Include inline hyperlinked source citations (Eg. [[1]](the YouTube Link) at relevant places in the report."
                "\n\n{text}\n\nFinal Summary:"

# %% [markdown]
# # City Council Report: Key Commercial Real Estate Impacts and Zoning Updates
# This report summarizes recent city council discussions and decisions relevant to the commercial real estate industry, focusing on zoning amendments, bylaw motions, property tax considerations, and development-related infrastructure. The information is extracted from council meeting transcripts and highlights changes, supporting arguments, and concerns raised by councillors and administration.
# ---
# ## 1. Schonsee Neighbourhood Rezoning and Development
# ### Overview
# - Location: East edge of Schonsee neighbourhood, west of 66 Street and north of 167 Avenue.
# - Site Context: Adjacent to a natural wetland with multi-use trails; surrounded by residential and commercial developments; vacant land to the north zoned for neighbourhood commercial use.
# - Transit: Bus service at 66 Street and 167 Avenue; multiple shared pathways and park spaces nearby.
# ### Proposed Changes
# - Rezoning to allow a mix of small-scale residential (up to 3 storeys), medium-scale housing (4 to 6 storeys), and neighbourhood-scale mixed-use development (up to 4 storeys).
# - Conservation zoning (NA) to protect wetland and natural areas while allowing passive recreation.
# - Amendments to the Edmonton North Area Structure Plan (ASP) and Schonsee Neighbourhood Structure Plan (NSP) to:
#   - Add commercial land use.
#   - Relocate and adjust low and medium density residential areas.
#   - Adjust park space and pedestrian connections.
#   - Realign NSP boundary to include Crystalina Nera Drive and connect to future 170 Avenue.
# ### Density and Development
# - Minor increase in residential density from 39 to 40 dwelling units per net residential hectare (an increase of 11 units).
# - Medium density zoning (RMH 23) allows up to six-storey buildings; no shift to lower RMH 16 was supported despite resident concerns about over-density.
# - The development is aligned with the City Plan goals to foster living locally, improve housing choices, and support commercial land use diversity.
# - Road infrastructure upgrades are planned, including a traffic circle at 167 Avenue and 66 Street, with phased twinning of 167 Avenue expected by 2026-2027.
# ### Community and Council Feedback
# - Some residents expressed concerns about increased density and traffic congestion.
# - Councillors acknowledged the need for road widening and infrastructure improvements to keep pace with development.
# - Administration committed to better community communication strategies, including potential use of QR codes and clearer project explanations.
# - The rezoning application was supported unanimously, emphasizing orderly development, conservation, and meeting residents’ daily needs [[2:38:40]](https://www.youtube.com/watch?v=775c_Ae9XYY&t=9520s), [[2:44:51]](https://www.youtube.com/watch?v=775c_Ae9XYY&t=9891s), [[2:48:00]](https://www.youtube.com/watch?v=775c_Ae9XYY&t=10080s), [[2:54:19]](https://www.youtube.com/watch?v=775c_Ae9XYY&t=10459s).
# ---
# ## 2. Direct Control Rezoning for Supportive Housing Facility
# ### Background
# - The council considered removing a sunset clause on a direct control zoning for a facility providing emergency shelter, transitional housing, and health services.
# - The original sunset clause was intended to limit the use to a temporary period but was removed to allow permanent use.
# - The facility provides integrated health care and overnight stays, aligning with city goals for supportive housing.
# ### Legal and Policy Considerations
# - Sunset clauses are typically used to incentivize development and avoid land speculation, not commonly applied to permanent infrastructure or social service uses.
# - The city does not consider the demographics of facility users in land use decisions but focuses on land use impacts and neighborhood compatibility.
# - There is no specific city policy directing decentralization of social services; the City Plan supports distributing core housing amenities city-wide.
# - Enforcement of shelter standards is primarily a provincial responsibility; the city’s role is limited to zoning and community standards bylaws addressing crime and disorder.
# ### Council Discussion
# - Some councillors expressed concern about repeated rezoning applications and associated fees for non-profits.
# - The city has built or planned 900 supportive housing units across 19 locations since 2019, indicating ongoing efforts to redistribute supportive housing.
# - Operational challenges such as litter, noise, and waste management were acknowledged, with increased city service levels in affected areas.
# - The motion to remove the sunset clause and allow permanent use was carried with one opposition [[1:13:41]](https://www.youtube.com/watch?v=775c_Ae9XYY&t=4421s), [[1:19:54]](https://www.youtube.com/watch?v=775c_Ae9XYY&t=4794s), [[1:22:52]](https://www.youtube.com/watch?v=775c_Ae9XYY&t=4972s).
# ---
# ## 3. Rezoning of a Problem Property Site to RSMH 12 Modifier (Small-Scale Residential Mixed-Use)
# ### Site Context
# - The property is currently split zoned (ARF and CN), limiting redevelopment options.
# - The site has been a hotspot for safety concerns, including violent incidents, loitering, and break-ins.
# - The community supports redevelopment to improve safety and provide affordable housing.
# ### Proposal
# - Rezoning to RSMH 12 modifier to allow small-scale residential mixed-use development.
# - The site is well connected to transit and commercial nodes, designated as urban mix in the district plan.
# - The proposal aligns with the City Plan’s vision for infill and 15-minute communities.
# ### Community Engagement
# - Seven residents were engaged; six supported redevelopment citing safety improvements.
# - One resident raised parking concerns, expected to be addressed during design and permitting.
# ### Council Deliberation
# - Councillors noted the site’s problematic status and supported redevelopment as a positive change.
# - The rezoning was carried unanimously, with recognition that the new zoning fits the site context better than the current split zoning [[3:26:36]](https://www.youtube.com/watch?v=775c_Ae9XYY&t=12396s), [[3:33:52]](https://www.youtube.com/watch?v=775c_Ae9XYY&t=12832s).
# ---
# ## 4. Alley and Infrastructure Considerations
# - Discussion on rear lane (alley) access highlighted that some alleys are underutilized and may be candidates for repurposing, including green infrastructure.
# - Waste collection in the area is primarily from the street rather than alleys, consistent with neighbourhood design.
# - Alley renewal programs may revisit functionality and capital investment priorities.
# - Road widening and twinning projects are underway or planned, with coordination between developers and the city to prioritize urgent infrastructure needs.
# - Communication to residents about construction timelines and impacts was identified as an area for improvement [[2:57:29]](https://www.youtube.com/watch?v=775c_Ae9XYY&t=10649s), [[3:03:48]](https://www.youtube.com/watch?v=775c_Ae9XYY&t=11028s), [[3:16:57]](https://www.youtube.com/watch?v=775c_Ae9XYY&t=11817s).
# ---
# ## Summary of Key Motions and Outcomes
# | Item | Description | Outcome | Notes |
# |-------|-------------|---------|-------|
# | Rezoning in Schonsee (RMH 23, mixed-use, conservation) | Supported with minor density increase and commercial land use addition | Carried unanimously | Includes infrastructure upgrades and wetland conservation |
# | Removal of sunset clause on direct control zoning for shelter | Supported with one opposition | Carried | Allows permanent use; no re-advertising required |
# | Rezoning of problem property to RSMH 12 modifier | Supported unanimously | Carried | Aims to improve safety and enable redevelopment |
# | Alley renewal and infrastructure upgrades | Ongoing planning and coordination | N/A | Potential repurposing of alleys; road widening phased |
# ---
# This report reflects council discussions and decisions as of the referenced meeting and is intended to inform real estate investors, brokers, developers, and other stakeholders about evolving land use policies, zoning changes, and infrastructure plans impacting commercial and residential development opportunities.
# ---
# ### Sources
# 1. Schonsee rezoning presentation and discussion [[2:38:40]](https://www.youtube.com/watch?v=775c_Ae9XYY&t=9520s)
# 2. Schonsee density and commercial use Q&A [[2:44:51]](https://www.youtube.com/watch?v=775c_Ae9XYY&t=9891s)
# 3. Road infrastructure and community communication [[2:48:00]](https://www.youtube.com/watch?v=775c_Ae9XYY&t=10080s)
# 4. Road widening and development timing [[2:54:19]](https://www.youtube.com/watch?v=775c_Ae9XYY&t=10459s)
# 5. Direct control zoning and sunset clause discussion [[1:13:41]](https://www.youtube.com/watch?v=775c_Ae9XYY&t=4421s)
# 6. Shelter operations and city role [[1:19:54]](https://www.youtube.com/watch?v=775c_Ae9XYY&t=4794s)
# 7. Supportive housing and zoning fees [[1:22:52]](https://www.youtube.com/watch?v=775c_Ae9XYY&t=4972s)
# 8. Problem property rezoning presentation [[3:26:36]](https://www.youtube.com/watch?v=775c_Ae9XYY&t=12396s)
# 9. Council debate and vote on problem property rezoning [[3:33:52]](https://www.youtube.com/watch?v=775c_Ae9XYY&t=12832s)
# 10. Alley access and waste collection discussion [[2:57:29]](https://www.youtube.com/watch?v=775c_Ae9XYY&t=10649s)
# 11. Road widening and developer coordination [[3:03:48]](https://www.youtube.com/watch?v=775c_Ae9XYY&t=11028s)
# 12. Alley renewal and infrastructure planning [[3:16:57]](https://www.youtube.com/watch?v=775c_Ae9XYY&t=11817s)

# %% [markdown]
# # City Council Report Summary: Implications for Commercial Real Estate and Infrastructure Investment
# This report consolidates key discussions and decisions from recent City of Edmonton council meetings relevant to commercial real estate investors, brokers, developers, and related stakeholders. It focuses on zoning and bylaw changes, capital budget adjustments, infrastructure renewal, property tax considerations, and strategic asset management impacting the real estate sector.
# ---
# ## 1. Bylaw Amendments and Infrastructure Projects
# - **Bylaw 21063 Amendment**: Council carried the amendment to Bylaw 20392 concerning the City of Edmonton Integrated Infrastructure Services Project, specifically the climate resilience facility upgrade at the A.M. Mithrie site. This bylaw passed all readings without opposition [[0:34:20]](https://www.youtube.com/watch?v=kEGYjFjDmBQ&t=2060s).
# - **Supplemental Capital Budget Adjustments (2023-2026)**: A $75 million net increase (approximately 0.7% of the $11 billion capital budget) was approved to address changing project needs, emerging issues, and priorities. This includes funding for neighbourhood renewal, safety/security enhancements, public recreation, cultural facilities, and building renovations. Some projects flagged for future funding include school site development, Windemere District Park construction, Rossdale Power Plant roof replacement, and transit projects [[1:10:17]](https://www.youtube.com/watch?v=kEGYjFjDmBQ&t=4217s).
# - **Emerging Infrastructure Projects**: The trestle bridge and culvert replacement project was confirmed as critical due to end-of-life infrastructure and erosion damage. The project also aims to improve ecological function by daylighting Mill Creek and stabilizing banks [[1:35:32]](https://www.youtube.com/watch?v=kEGYjFjDmBQ&t=5732s).
# ---
# ## 2. Capital Renewal Funding Gap and Asset Management
# - **Renewal Funding Deficit**: The city faces a significant infrastructure renewal funding gap. The 2027-2030 renewal requirement is estimated at $4.4 billion, with forecasted funding of $2.8 billion, leaving a $1.6 billion shortfall. Underfunding renewal risks increased liabilities, service declines, higher operating costs, and future funding pressures [[2:31:48]](https://www.youtube.com/watch?v=kEGYjFjDmBQ&t=9108s).
# - **Disposition and Rationalization of City-Owned Assets**: Administration is conducting program-level reviews of city-owned facilities, including internal buildings (waste management, fire stations, police stations, aquatics) and non-city commercial or leased properties. These efforts aim to rationalize asset ownership but are not expected to significantly reduce the renewal deficit in the short term. Disposition is a long-term strategy with associated costs and complexities [[2:35:20]](https://www.youtube.com/watch?v=kEGYjFjDmBQ&t=9320s), [[6:01:54]](https://www.youtube.com/watch?v=kEGYjFjDmBQ&t=21714s).
# - **Property Tax and Funding Sources**: Council acknowledged that property taxes and user fees remain the primary sources to address renewal funding gaps. Provincial grant funding is constrained and unlikely to return to previous levels, necessitating reliance on municipal revenue sources. Discussions included potential dedicated tax levy increases for renewal funding starting in 2026, with further analysis planned for the fall supplementary budget [[5:33:36]](https://www.youtube.com/watch?v=kEGYjFjDmBQ&t=20016s), [[5:52:40]](https://www.youtube.com/watch?v=kEGYjFjDmBQ&t=21160s).
# ---
# ## 3. Growth-Related Infrastructure and Capital Prioritization
# - **Arterial Roads and Growth Pressures**: Council highlighted significant growth-related pressures on arterial roads, especially in southeast Edmonton (e.g., 66th Street, 91st Street). Previous reports identified key priorities such as 167th Avenue, Parsons Road at Ellerslie, and 215 Street. However, rapid population growth has intensified demands, prompting a motion for administration to provide an updated prioritization report on mobility infrastructure, including cost escalations and tariff impacts, by Q1 2026 [[6:05:16]](https://www.youtube.com/watch?v=kEGYjFjDmBQ&t=21916s).
# - **Criteria for Emerging Projects**: Emerging capital projects are prioritized based on safety, legislative mandates, eligibility for external funding, and potential significant benefits to city prosperity. Growth pressures are considered primarily during the four-year budget cycle due to the volume of growth projects and limited interim funding [[1:52:16]](https://www.youtube.com/watch?v=kEGYjFjDmBQ&t=6736s), [[1:38:48]](https://www.youtube.com/watch?v=kEGYjFjDmBQ&t=5928s).
# - **School Infrastructure and Joint Use Agreements**: Infrastructure investments related to new school sites (e.g., District Park junior high/high schools) are mandated under joint use agreements. Administration is exploring opportunities to secure provincial funding through programs like the School Accelerator Program, though no confirmed commitments have been received [[1:22:41]](https://www.youtube.com/watch?v=kEGYjFjDmBQ&t=4961s).
# ---
# ## 4. Neighbourhood Renewal and Capital Project Scope
# - **Neighbourhood and Alley Renewal Projects**: An $86.5 million neighbourhood renewal project was discussed, with concerns raised about varying project scopes and costs across different neighbourhoods (e.g., Castle Downs vs. Lessard). Planning and design phases are complete, and the current budget covers construction costs. Delaying approval to conduct detailed scope vs. cost reviews would postpone entire neighbourhood renewal timelines [[1:13:18]](https://www.youtube.com/watch?v=kEGYjFjDmBQ&t=4398s).
# - **Scope Changes and Budget Increases**: Scope changes triggering new funding requests arise from both internal project management adjustments and external factors such as stakeholder expectations or integration requirements (e.g., Lewis Farms District Park project). Detailed explanations for scope changes are provided in budget attachments, with some requiring in-camera discussion due to sensitive information [[1:55:39]](https://www.youtube.com/watch?v=kEGYjFjDmBQ&t=6939s).
# ---
# ## 5. Public Engagement and Policy Updates
# - **Public Engagement in Budgeting**: The city conducts robust public engagement during the four-year budget cycle, including focus groups and community outreach at festivals. Feedback from diverse groups informs service prioritization and budget decisions, such as community safety and well-being initiatives [[4:48:38]](https://www.youtube.com/watch?v=kEGYjFjDmBQ&t=17318s).
# - **Sustainable Procurement and Inclusion**: Annual reports on sustainable procurement policies are provided to council. Facilities have adopted inclusive practices such as allowing smudging ceremonies, supporting diverse cultural events, and maintaining open community spaces [[4:48:38]](https://www.youtube.com/watch?v=kEGYjFjDmBQ&t=17318s).
# ---
# ## Summary of Key Impacts for Commercial Real Estate Stakeholders
# - **Infrastructure Renewal Funding Gap**: The significant shortfall in renewal funding may impact the condition and availability of city-owned infrastructure, potentially affecting property values and development feasibility.
# - **Capital Budget Adjustments**: Approved supplemental budgets and emerging projects signal ongoing investment in neighbourhood renewal, safety, and public amenities, which can enhance community attractiveness and support real estate development.
# - **Growth-Driven Infrastructure Needs**: Increasing population and traffic congestion pressures necessitate updated arterial road investments, influencing accessibility and development potential in growth areas.
# - **Asset Rationalization and Disposition**: Long-term strategies to optimize city-owned real estate assets may create opportunities or risks for commercial real estate markets depending on disposition outcomes.
# - **Property Tax Considerations**: Potential property tax increases dedicated to renewal funding could affect carrying costs for property owners and developers.
# - **Engagement and Policy Transparency**: Continued public engagement and transparent reporting support informed decision-making and community alignment with development initiatives.
# ---
# This summary reflects council discussions and decisions as presented in the referenced meeting recordings and does not include external analysis or opinion.
# ---
# ### References
# 1. Bylaw 21063 Amendment and Voting – [YouTube 34:20](https://www.youtube.com/watch?v=kEGYjFjDmBQ&t=2060s)
# 2. Supplemental Capital Budget Presentation – [YouTube 70:17](https://www.youtube.com/watch?v=kEGYjFjDmBQ&t=4217s)
# 3. Trestle Bridge and Culvert Replacement – [YouTube 95:32](https://www.youtube.com/watch?v=kEGYjFjDmBQ&t=5732s)
# 4. Renewal Funding Gap Overview – [YouTube 152:48](https://www.youtube.com/watch?v=kEGYjFjDmBQ&t=9108s)
# 5. Asset Disposition and Rationalization – [YouTube 155:20](https://www.youtube.com/watch?v=kEGYjFjDmBQ&t=9320s)
# 6. Disposition Cost and Strategy – [YouTube 362:00](https://www.youtube.com/watch?v=kEGYjFjDmBQ&t=21714s)
# 7. Property Tax and Funding Sources Discussion – [YouTube 333:36](https://www.youtube.com/watch?v=kEGYjFjDmBQ&t=20016s)
# 8. Dedicated Renewal Fund and Tax Levy – [YouTube 353:00](https://www.youtube.com/watch?v=kEGYjFjDmBQ&t=21160s)
# 9. Arterial Roads Prioritization Motion – [YouTube 363:36](https://www.youtube.com/watch?v=kEGYjFjDmBQ&t=21916s)
# 10. Emerging Project Criteria – [YouTube 112:16](https://www.youtube.com/watch?v=kEGYjFjDmBQ&t=6736s)
# 11. Growth Pressures and Budget Cycle – [YouTube 98:48](https://www.youtube.com/watch?v=kEGYjFjDmBQ&t=5928s)
# 12. School Infrastructure Funding – [YouTube 81:01](https://www.youtube.com/watch?v=kEGYjFjDmBQ&t=4961s)
# 13. Neighbourhood Renewal Project Discussion – [YouTube 73:18](https://www.youtube.com/watch?v=kEGYjFjDmBQ&t=4398s)
# 14. Scope Changes Explanation – [YouTube 115:39](https://www.youtube.com/watch?v=kEGYjFjDmBQ&t=6939s)
# 15. Public Engagement and Inclusion – [YouTube 288:38](https://www.youtube.com/watch?v=kEGYjFjDmBQ&t=17318s)

# %%
"Combine the following city council transcript snippets into a single coherent markdown report. Extract"
                "important information that could impact the commercial real estate industry, including zoning"
                "and bylaw changes, carried bylaw motions, property tax discussions, general discussion about real estate, or topics"
                "relevant to real estate investors, brokers or developers, etc. Make the report as concise as"
                "possible while using as many facts from the text as you can. Focus on changes that are happening"
                "and any arguments for or against the changes. Only include information that was directly"
                "discussed in the text and do not add any of your own opinions or interpretations of the information."
                "IMPORTANT: Include inline hyperlinked source citations (Eg. [[1]](the YouTube Link)."
                "\n\n{text}\n\nFinal Summary:"

# %% [markdown]
# # City Council Report: Commercial Real Estate and Zoning Updates
# This report summarizes key discussions and decisions from the recent city council meeting relevant to the commercial real estate industry, including zoning amendments, bylaw motions, property tax considerations, and infrastructure impacts affecting developers, investors, and brokers.
# ---
# ## 1. Rezoning and Development in Schonsee Neighbourhood
# - **Location & Context:**
#   The subject site is located west of 66 Street and north of 167 Avenue, at the eastern edge of the Schonsee neighbourhood. It is adjacent to a natural wetland with multi-use trails, residential and commercial developments, and vacant land zoned for neighbourhood commercial use. Transit service is available at 66 Street and 167 Avenue, with shared pathways and park spaces nearby.
# - **Proposed Zoning Changes:**
#   - Small-scale residential up to 3 storeys (RSF zone)
#   - Medium-scale housing approximately 4 to 6 storeys (RMH 16 and H 23 zones)
#   - Neighbourhood-scale mixed-use development up to 4 storeys (MUN zone)
#   - Conservation and restoration of natural areas (NA zone)
#   - Adjustments to the Schonsee Neighbourhood Structure Plan (NSP) and Edmonton North Area Structure Plan (ASP) to:
#     - Add commercial land use
#     - Relocate and adjust low and medium density residential areas
#     - Modify park space and pedestrian connections
#     - Realign NSP boundary to include Crystalina Nera Drive and connect with future 170 Avenue
# - **Density Impact:**
#   The residential density will increase slightly from 39 to 40 dwelling units per net residential hectare, equating to an additional 11 dwelling units. This increase involves approximately 0.46 hectares moving into medium density from other land uses.
# - **Building Height Considerations:**
#   The RMH 23 zone allows up to 6 storeys (approximately 23 meters). Alternatives such as RMH 16 (lower height) were considered but not pursued due to proximity to transit and mixed-use sites. The higher density and height are intended to provide a variety of housing types and better align with transit-oriented development goals.
# - **Infrastructure and Road Upgrades:**
#   - A traffic circle at 167 Avenue and 66 Street is under construction, expected to be completed next year.
#   - Road widening (twinning) of 167 Avenue and 66 Street is planned but expected to be phased over several years, with some work anticipated in 2026 or 2027.
#   - Developers in the area will contribute to these upgrades.
#   - Discussions about swapping responsibilities between the city and developers to prioritize urgent infrastructure needs have occurred, with precedent set in other areas.
# - **Community Engagement and Concerns:**
#   - Administration reported minimal public opposition, with only two inquiries about built form and applicant intent.
#   - Some councillors and residents expressed concerns about incremental density increases and traffic congestion at key intersections.
#   - Communication to residents about development and infrastructure plans was noted as insufficient, with suggestions to improve transparency using technology such as QR codes.
# - **Council Decision:**
#   Administration recommended support for the application as it aligns with the City Plan’s goals of fostering growth in established neighbourhoods, providing housing choices, conserving natural areas, and supporting commercial uses. The motion was carried unanimously [[2:38:40]](https://www.youtube.com/watch?v=775c_Ae9XYY&t=9520s), [[2:44:51]](https://www.youtube.com/watch?v=775c_Ae9XYY&t=9891s), [[2:48:00]](https://www.youtube.com/watch?v=775c_Ae9XYY&t=10080s).
# ---
# ## 2. Rezoning for Transitional and Supportive Housing (Direct Control Zone)
# - **Background:**
#   A direct control zoning application was discussed to allow a permanent use for a facility providing emergency shelter, transitional housing, and health services, replacing a previous temporary zoning with a sunset clause.
# - **Sunset Clause Discussion:**
#   - The original zoning included a sunset clause limiting emergency shelter use to a temporary period.
#   - The current application seeks to remove the sunset clause, making the use permanent.
#   - Council discussed the rarity of sunset clauses in permanent infrastructure zoning, noting they are typically used to incentivize development and avoid speculation, not to limit social service uses.
#   - Temporary uses like parking lots have used sunset clauses, but not permanent shelter facilities.
# - **Community and Policy Considerations:**
#   - The city does not consider the demographics of facility users in land use decisions but does consider impacts such as crime and disorder.
#   - There is no specific city policy directing decentralization of social services; however, the City Plan supports distributing core housing amenities city-wide.
#   - The facility aligns with integrated health care models and supportive housing strategies, with the city having planned or shovel-ready 900 supportive units across 19 locations since 2019.
# - **Operational and Financial Implications:**
#   - The applicant, a non-profit organization, incurs significant costs and administrative work for rezoning applications, including direct control zones.
#   - Requiring repeated rezoning applications with sunset clauses imposes financial burdens on non-profits serving vulnerable populations.
# - **Council Deliberation and Outcome:**
#   - Some councillors expressed concerns about the indefinite nature of the zoning and the need for ongoing advocacy with provincial authorities regarding shelter standards and operations.
#   - The motion to remove the sunset clause and allow permanent use was carried, with no requirement for re-advertising if council limits the time in the future [[1:13:41]](https://www.youtube.com/watch?v=775c_Ae9XYY&t=4421s), [[1:19:54]](https://www.youtube.com/watch?v=775c_Ae9XYY&t=4794s), [[1:22:52]](https://www.youtube.com/watch?v=775c_Ae9XYY&t=4972s).
# ---
# ## 3. Alleyway and Access Considerations in Residential Developments
# - **Alleyway Use and Renewal:**
#   - Some alleys in the discussed neighbourhoods are underutilized and unpaved.
#   - The city is considering repurposing such alleys as part of the alley renewal program, potentially for green infrastructure or other uses rather than repaving.
#   - Waste collection in these areas is typically from the street rather than alleys, consistent with neighbourhood design.
# - **Access and Built Form:**
#   - New developments are encouraged to take access from alleys where practical to enhance pedestrian safety and asset use.
#   - In some cases, access from the street is accepted due to site constraints.
#   - Direct control zoning is used to regulate built form and uses to address community concerns, including design elements like landscaping and driveway width.
# ---
# ## 4. General Council Process and Motions
# - Several bylaw motions related to the above rezonings were carried unanimously, including first, second, and third readings.
# - Items not dealt with during the meeting were postponed to the next scheduled meeting on August 18th.
# - Council emphasized the need for better communication with residents regarding development timelines, infrastructure projects, and impacts.
# ---
# # Summary
# The council approved rezonings that slightly increase residential density and add commercial uses in the Schonsee neighbourhood, supporting mixed-use development and conservation of natural areas. Infrastructure upgrades, including road widening and traffic circle construction, are underway but will be phased over several years, with developer contributions tied to development progress.
# A direct control zoning amendment was approved to remove a sunset clause on emergency shelter use, allowing permanent operation of a transitional/supportive housing facility, reflecting the city’s broader housing strategy.
# Discussions highlighted the importance of clear communication with residents, strategic infrastructure planning, and balancing development with community concerns about density, safety, and services.
# ---
# ### Sources
# 1. Schonsee Neighbourhood Rezoning Presentation and Discussion [[YouTube 9520s]](https://www.youtube.com/watch?v=775c_Ae9XYY&t=9520s)
# 2. Density and Infrastructure Questions [[YouTube 9891s]](https://www.youtube.com/watch?v=775c_Ae9XYY&t=9891s)
# 3. Council Vote and Road Upgrades [[YouTube 10080s]](https://www.youtube.com/watch?v=775c_Ae9XYY&t=10080s)
# 4. Shelter Use and Sunset Clause Discussion [[YouTube 4421s]](https://www.youtube.com/watch?v=775c_Ae9XYY&t=4421s)
# 5. Shelter Zoning and Legal Considerations [[YouTube 4794s]](https://www.youtube.com/watch?v=775c_Ae9XYY&t=4794s)
# 6. Supportive Housing Policy and Operational Questions [[YouTube 4972s]](https://www.youtube.com/watch?v=775c_Ae9XYY&t=4972s)

# %% [markdown]
# ## 1. Bylaw Amendments and Infrastructure Projects
# - **Bylaw 21063 Amendment**: Council carried the amendment to Bylaw 20392 concerning the City of Edmonton Integrated Infrastructure Services Project, specifically the climate resilience facility upgrade at an unspecified location ("mithrie") [[0:34:20]](https://www.youtube.com/watch?v=kEGYjFjDmBQ&t=2060s).
# - **Other Bylaws**: Third and final readings of Bylaws 21138 and 21139 were carried without debate [[0:31:01]](https://www.youtube.com/watch?v=kEGYjFjDmBQ&t=1861s).
# ---
# ## 2. Capital Budget Adjustments and Infrastructure Renewal
# - **Spring 2025 Supplemental Capital Budget**: The city approved a $75 million net increase to the 2023-2026 capital budget (approximately 0.7% of the $11 billion budget). Adjustments include:
#   - New neighbourhood renewal reserve funding for 2027 and beyond.
#   - Neighbourhood renewal work, safety and security enhancements.
#   - Public recreation, cultural facility renovations.
#   - Offsets from federal funding for housing projects in Garneau.
#   - Cancellation of some projects like the e-park machine upgrades and Indigenous cultural centre [[1:10:17]](https://www.youtube.com/watch?v=kEGYjFjDmBQ&t=4217s).
# - **Emerging Projects Flagged**: Base-level development for school sites, Windemere district park construction, Rossdale power plant roof replacement, and several transit projects were noted as upcoming needs [[1:10:17]](https://www.youtube.com/watch?v=kEGYjFjDmBQ&t=4217s).
# - **Capital Budget Shortfall and Renewal Gap**:
#   - The city faces a significant shortfall in the 2023-26 capital budget, projected to continue into 2027-30.
#   - Renewal requirements for 2027-30 are estimated at $4.4 billion, with forecasted funding of $2.8 billion, leaving a $1.6 billion gap.
#   - Underfunding renewal risks increased liabilities, service declines, higher operating costs, and future funding pressures [[2:31:48]](https://www.youtube.com/watch?v=kEGYjFjDmBQ&t=9108s).
# - **Prioritization Criteria for Capital Projects**: Projects prioritized include those mandated by legislation, safety concerns, eligible for external funding, or showing significant benefit to city prosperity [[2:31:48]](https://www.youtube.com/watch?v=kEGYjFjDmBQ&t=9108s).
# - **Scope Changes in Projects**: Scope changes triggering new funding requests vary by project and can be due to internal design adjustments or external factors such as integration with school districts (e.g., Lewis Farms district park) [[1:55:39]](https://www.youtube.com/watch?v=kEGYjFjDmBQ&t=6939s).
# ---
# ## 3. Asset Renewal and Disposition
# - **Renewal Deficit Concerns**: Council members expressed concern over a long-standing renewal deficit estimated at $34 billion in assets with a matching renewal cost, highlighting a persistent funding gap [[2:35:20]](https://www.youtube.com/watch?v=kEGYjFjDmBQ&t=9320s).
# - **Disposition Strategy**:
#   - The city is reviewing internally facing buildings (city operations, waste management), fire stations, police stations, and aquatic facilities for potential rationalization.
#   - Disposition is a long-term strategy and will not immediately reduce the renewal deficit.
#   - Cost is involved in disposition, so it is not a quick source of funding [[5:33:36]](https://www.youtube.com/watch?v=kEGYjFjDmBQ&t=20016s).
# - **Tax Uplift and Infill**: Tax uplift from infill and industrial action plans may help fund renewal but must be carefully managed to avoid diverting funds away from renewal needs [[5:33:36]](https://www.youtube.com/watch?v=kEGYjFjDmBQ&t=20016s).
# ---
# ## 4. Property Tax and Funding Discussions
# - **Property Tax as Primary Renewal Funding Source**:
#   - Due to constrained provincial and federal funding, property taxes remain the main source to address renewal funding gaps.
#   - User fees may contribute to operational costs but have limited applicability to capital renewal [[5:33:36]](https://www.youtube.com/watch?v=kEGYjFjDmBQ&t=20016s).
# - **Potential Tax Levy Increase**:
#   - Council discussed options for a dedicated renewal fund supported by a property tax levy increase starting in 2026.
#   - Some members advocated for a 2-4% tax levy increase to close the renewal gap.
#   - Administration indicated a plan to return with options in the fall supplementary budget adjustment [[5:52:40]](https://www.youtube.com/watch?v=kEGYjFjDmBQ&t=21160s).
# ---
# ## 5. Neighbourhood Renewal and Infrastructure Projects
# - **Neighbourhood and Alley Renewal Program**:
#   - $86.5 million allocated for neighbourhood and alley renewal projects.
#   - Planning and design phases are mostly complete; funds are primarily for construction.
#   - Delaying approval would postpone entire neighbourhood projects.
#   - Council requested more detailed scope and cost reviews, potentially via the Infrastructure Committee [[1:13:18]](https://www.youtube.com/watch?v=kEGYjFjDmBQ&t=4398s).
# - **Sidewalks and Road Conditions**: Councillors noted deteriorating sidewalks, curbs, drainage, and pervasive potholes, emphasizing the need for timely renewal to avoid escalating maintenance costs [[1:19:39]](https://www.youtube.com/watch?v=kEGYjFjDmBQ&t=4779s).
# - **Specific Infrastructure Projects**:
#   - Trestle bridge and culvert replacement due to end-of-life and erosion damage; project includes ecological restoration and improved water flow [[1:35:32]](https://www.youtube.com/watch?v=kEGYjFjDmBQ&t=5732s).
#   - Rossdale power plant roof replacement focused on emergency rehabilitation to maintain future redevelopment options [[1:29:15]](https://www.youtube.com/watch?v=kEGYjFjDmBQ&t=5355s).
# ---
# ## 6. Growth-Related Infrastructure and Arterial Roads
# - **Growth Pressures and Capital Budget**:
#   - Rapid population growth has increased pressure on arterial roads and infrastructure.
#   - Council expressed frustration that growth-related projects are often deferred to the four-year budget cycle, limiting responsiveness.
#   - Emerging issues related to arterial roads (e.g., 66th Street, 91st Street, 167th Avenue, Parsons Road) are being monitored, with a report on prioritization expected in Q1 2026 [[6:05:16]](https://www.youtube.com/watch?v=kEGYjFjDmBQ&t=21916s).
# - **Motion for Mobility Infrastructure Update**: A motion was carried directing administration to provide an update on prioritization of mobility infrastructure, including arterial roads, reflecting changed conditions such as growth and cost escalation [[6:05:16]](https://www.youtube.com/watch?v=kEGYjFjDmBQ&t=21916s).
# - **Funding Criteria for Growth Projects**: Growth projects are generally not funded outside the four-year budget cycle unless safety-related or eligible for external grants. The city prioritizes projects with multi-level government investment [[1:38:48]](https://www.youtube.com/watch?v=kEGYjFjDmBQ&t=5928s).
# ---
# ## 7. External Funding and Grants
# - **Provincial and Federal Funding**:
#   - Constrained provincial funding is largely tied to growth projects and specific priorities.
#   - Unconstrained funding (for renewal) is limited and uncertain.
#   - The city continues to advocate for increased funding but expects to rely more on local sources [[5:33:36]](https://www.youtube.com/watch?v=kEGYjFjDmBQ&t=20016s).
# - **Canada Public Transit Fund**: The city is preparing to meet provincial requirements for matching funds and is engaged in ongoing discussions to expedite approvals [[1:35:32]](https://www.youtube.com/watch?v=kEGYjFjDmBQ&t=5732s).
# - **School Infrastructure**: The city is obligated under joint use agreements to provide infrastructure for new schools. Administration has reached out to the province to explore funding opportunities through programs like the School Accelerator Program [[1:29:15]](https://www.youtube.com/watch?v=kEGYjFjDmBQ&t=5355s).
# ---
# ## 8. Public Engagement and Policy Updates
# - **Public Engagement in Budgeting**: The city conducts robust public engagement during the four-year budget cycle, including focus groups and community events, to inform budget priorities [[4:48:38]](https://www.youtube.com/watch?v=kEGYjFjDmBQ&t=17318s).
# - **Sustainable Procurement**: An annual report on sustainable procurement policy is provided to council, tracking progress on related metrics [[4:48:38]](https://www.youtube.com/watch?v=kEGYjFjDmBQ&t=17318s).
# ---
# # Summary
# The City of Edmonton council has approved amendments to infrastructure-related bylaws and a supplemental capital budget increase of $75 million for 2023-26, focusing on neighbourhood renewal, safety, and cultural facilities. However, a significant infrastructure renewal funding gap remains, projected at $1.6 billion for 2027-30, with property taxes identified as the primary funding source to address this deficit.
# Growth-related infrastructure, particularly arterial roads, faces increasing pressure due to rapid population growth, prompting motions for updated prioritization and funding strategies. The city continues to pursue disposition of some assets to manage renewal costs but recognizes this as a long-term strategy.
# External funding remains constrained and tied to growth projects, with limited support for renewal. The city is actively engaging with provincial programs to secure funding for transit and school infrastructure.
# Neighbourhood renewal projects are advancing, with some council members requesting more detailed scope and cost reviews. Public engagement remains a key component of budget planning.
# Overall, the council is balancing renewal needs, growth pressures, and fiscal constraints, with ongoing discussions about property tax increases and strategic prioritization to sustain Edmonton’s infrastructure and support economic prosperity.
# ---
# **Source:** City of Edmonton Council Meeting Videos [[1]](https://www.youtube.com/watch?v=kEGYjFjDmBQ)

# %% [markdown]
# # 0.2 Temperature:

# %% [markdown]
# ---
# ### Executive Summary
# Edmonton City Council is undertaking significant reforms to its zoning bylaws and development policies, with wide-ranging implications for the commercial real estate sector. Key issues include proposed reductions in allowable residential unit caps, new design and energy requirements, the removal of parking minimums, and a strategic focus on higher-density development along transit corridors. These changes are intended to support population growth, housing affordability, and sustainable urban development, but they also introduce new risks and uncertainties for developers, investors, brokers, and property owners. The evolving regulatory environment, combined with community resistance and calls for greater consultation, underscores the need for clear transition rules, policy stability, and proactive stakeholder engagement.
# ---
# ### Key Zoning and Bylaw Changes
# - **Unit Cap Reduction:**
#   - Council is considering reducing the maximum units per residential lot from eight to six, despite strong demand for larger multiunit projects (79% of recent row house permits in mature neighborhoods were for seven or more units).
#   - This rollback is contentious, with concerns about undermining project viability, reducing housing supply, and impacting financing eligibility (e.g., CMHC programs).
# - **Progressive Reforms and Parking Minimums:**
#   - Edmonton has eliminated parking minimums and updated its zoning bylaw, positioning itself as a leader in zoning reform among Canadian cities.
#   - The city’s current allowance of up to six units per lot exceeds the density permitted in many peer municipalities.
# - **Design and Development Standards:**
#   - New requirements, including energy modeling and stricter controls on building size, depth, and setbacks, are being debated. Developers warn these could increase costs and reduce design flexibility, especially on smaller or irregular lots.
#   - There are calls for context-sensitive standards and flexibility, referencing successful models from other cities (e.g., Calgary).
# - **Targeted Density and Urban Growth:**
#   - Higher-density development is being prioritized along transit corridors and in areas with robust infrastructure, rather than through blanket upzoning, to balance growth with neighborhood preservation.
# ---
# ### Regulatory Environment and Market Impacts
# - **Transition Periods and Investor Confidence:**
#   - Abrupt regulatory changes, especially without reasonable transition periods or grandfathering of existing applications, are increasing financial risk and eroding investor confidence.
#   - Developers report significant sunk costs and holding expenses, with some projects facing delays or cancellations due to uncertainty.
# - **Permit Processing and Administrative Delays:**
#   - Anticipation of new bylaws has led to delays in permit processing, increasing holding costs and financial risk for ongoing projects.
# - **Legal and Property Rights Concerns:**
#   - Some property owners argue that new restrictions infringe on property rights and may be subject to legal challenge, referencing provincial and federal frameworks.
# ---
# ### Community and Political Dynamics
# - **Community Resistance:**
#   - Residents express concerns about loss of sunlight, privacy, and neighborhood character due to infill and higher-density rentals. Proposals include development moratoriums, citizen appeal mechanisms, and more robust consultation processes.
#   - Notification requirements for adjacent property owners are being considered to improve transparency and communication.
# - **Support for Densification:**
#   - Other stakeholders support the reforms, citing increased housing options, fiscal and environmental sustainability, and the relatively modest scale of densification to date.
# ---
# ### Housing Supply, Urban Growth, and Market Context
# - **Population Growth and Housing Supply:**
#   - Edmonton’s population is projected to grow moderately in the coming years. While there is no acute housing supply crisis, most new infill is purpose-built rental, with limited affordable homeownership options.
#   - Allowing up to six units per lot is seen as a way to incrementally improve affordability and housing diversity.
# - **Urban Sprawl vs. Infill:**
#   - Council debates continue over the balance between limiting suburban expansion and promoting infill. Some argue that containment policies may inadvertently increase housing costs, while others emphasize the need to protect neighborhood character and infrastructure.
# ---
# ### Implications for Commercial Real Estate Stakeholders
# 1. **Development Opportunities:**
#    - Progressive zoning reforms and the removal of parking minimums create new opportunities for multiunit and mixed-use projects, particularly along transit corridors.
# 2. **Investment Risk and Project Viability:**
#    - Sudden regulatory changes, especially without clear transition periods, increase risk for developers and may deter future investment. Reduced unit caps and permit delays could impact project financials and property values.
# 3. **Community Engagement and Approval Processes:**
#    - Heightened community resistance and calls for more robust consultation may lengthen approval timelines and increase project complexity.
# 4. **Market Positioning:**
#    - Edmonton’s reforms may enhance its attractiveness to investors and developers seeking a more flexible, pro-growth environment, but only if policy stability and clear communication are maintained.
# 5. **Legal and Policy Considerations:**
#    - Potential legal challenges regarding property rights and due process could introduce further uncertainty.
# ---
# ### Recommendations for Industry Stakeholders
# - **Monitor bylaw amendments and participate in consultations to shape policy outcomes.**
# - **Plan for potential delays and regulatory changes in project timelines and financial models.**
# - **Engage with community groups to address concerns and build support for new developments.**
# - **Advocate for clear, evidence-based policy rationales and reasonable transition periods for new regulations.**
# - **Stay informed about legal developments related to property rights and zoning appeals.**
# ---
# ### Conclusion
# Edmonton’s evolving zoning and bylaw landscape presents both opportunities and challenges for the commercial real estate sector. While reforms support higher density and more flexible development, regulatory uncertainty, community resistance, and the lack of clear transition rules pose risks to project viability and investor confidence. A balanced, transparent, and stable regulatory approach—coupled with robust stakeholder engagement—will be essential for sustaining a healthy commercial real estate market and meeting Edmonton’s housing and growth objectives. Industry professionals should remain vigilant, proactive, and engaged as the city’s policy environment continues to evolve.

# %% [markdown]
# # 0.0 Temperature:

# %% [markdown]
# **Comprehensive Report on Recent Zoning, Bylaw, and Development Permit Changes Impacting Edmonton’s Commercial Real Estate Industry**
# Recent developments in Edmonton’s zoning bylaws, development permit processes, and urban growth policies have significant implications for the commercial real estate sector, including investors, developers, brokers, and planners. These changes reflect the city’s efforts to manage urban densification, protect neighborhood character, and balance growth with infrastructure capacity, but have also raised concerns about project viability, housing supply, and investor confidence. The following summarizes key issues and their potential impact on the industry.
# ---
# ### 1. **Zoning Bylaw Amendments: Unit Caps, Setbacks, and Building Limits**
# - **Reduction in Maximum Units per Lot:**
#   A major regulatory shift caps multiplex developments in RS (single-family residential) zones at six units per lot, down from the previous maximum of eight. This change particularly affects mid-block infill and row house projects, where recent permits showed 79% included seven or more units. The cap threatens to constrain housing supply and reduce the diversity of rental options, especially purpose-built rentals, potentially exacerbating affordability challenges in mature neighborhoods.
# - **Setback Regulations and Building Depth Limits:**
#   The city maintains a 4.5-metre front yard setback, which contrasts with existing neighborhood setbacks often ranging from 8 to 9 metres. Stakeholders advocate for more context-sensitive, flexible setbacks that better reflect established neighborhood character. Proposed side yard setback adjustments allow steps to project into side yards to improve accessibility and drainage. Additionally, building depth is limited to 50% of lot depth in certain residential zones, including areas near schools and universities. Developers argue these restrictions are arbitrary for larger lots (800-900 m²), forcing reductions in building footprints and unit sizes, undermining project feasibility and affordability.
# - **Lack of Data-Driven Rationale:**
#   Industry participants criticize the absence of clear, evidence-based justification for the six-unit cap and other restrictions, calling for transparent, data-supported policy decisions and enhanced community consultation.
# ---
# ### 2. **Financial and Operational Impacts on Developers and Investors**
# - **Abrupt Policy Changes Without Transition Periods:**
#   The sudden implementation of zoning amendments, without grandfathering or transition timelines, has forced costly redesigns, delayed projects by six to nine months or more, and increased holding costs. Sunk design and related fees per lot exceed $150,000, with additional soft costs such as appraisals, construction charges, and interest payments compounding financial burdens.
# - **Erosion of Investor Confidence:**
#   The lack of a clear, fair transition framework undermines trust in the city’s planning process. Investors feel penalized despite prior compliance, risking reduced investment inflows and destabilization of the local real estate market, which could further drive up housing prices.
# - **Calls for Transition Periods and Predictability:**
#   Stakeholders advocate for a 12-month transition period for new projects and a more predictable, transparent zoning policy environment to safeguard project viability and maintain investor confidence.
# ---
# ### 3. **Neighborhood Character, Infrastructure, and Community Concerns**
# - **Preserving Mature Neighborhoods:**
#   Residents and some developers express concerns about rapid densification’s impact on sunlight, privacy, property enjoyment, and infrastructure strain (parking, landscaping, waste management). There are calls for rigorous planning measures such as shadow studies, stricter limits on building bulk and height, and design guidelines that respect neighborhood character.
# - **Community Engagement and Moratorium Proposals:**
#   Some community members urge a temporary moratorium on certain development types to allow for better citizen consultation and the establishment of appeal mechanisms. Proposals include forming dedicated project teams with city planners and independent facilitators to explore alternatives and timelines.
# ---
# ### 4. **Development Permit Process Enhancements and Compliance Support**
# - **Improved Notification Requirements:**
#   The city proposes enhanced development permit notification rules, requiring direct notification to adjacent property owners—including those across alleys—upon application submission. This aims to restore transparency and early communication between developers and neighbors.
# - **Infill Liaison Team and Builder Education:**
#   The city’s Infill Liaison Team facilitates communication among stakeholders, analyzes complaints, supports compliance, and provides targeted education for new builders to improve adherence to infill regulations. Ongoing monitoring and enforcement enhancements are recommended.
# - **Extended Compliance Deadlines:**
#   A proposed extension of development permit compliance deadlines to January 2024 is intended to give design teams more time to adapt to zoning changes without disrupting project pipelines.
# ---
# ### 5. **Strategic Urban Growth and Land Use Policies**
# - **Focus on Infill and Densification:**
#   Edmonton’s strategic plan aims to accommodate 600,000 new residents within the Anthony Henday ring road, emphasizing increased density near transit corridors to reduce urban sprawl and protect greenbelt areas. The 2024 zoning bylaw renewal, including the removal of parking minimums, supports this vision.
# - **Balancing Growth with Infrastructure and Affordability:**
#   While population growth forecasts are moderate, concerns remain about the complexity and fragility of zoning frameworks in supporting sustainable densification without compromising neighborhood character or affordability. Restricting suburban expansion may increase housing costs and accelerate demolition of older homes for higher-density developments.
# - **Consistency and Compatibility:**
#   Proposed bylaws seek to ensure new developments blend physically with existing neighborhoods, encouraging incremental densification through duplexes, triplexes, and basement suites to maintain community cohesion.
# ---
# ### 6. **Implications for Commercial Real Estate Stakeholders**
# - **Developers and Investors:**
#   Must carefully navigate evolving zoning restrictions affecting density, building size, and unit counts, which impact project feasibility, financing, and timelines. Early engagement with city planners and awareness of notification changes are critical to managing risk. Advocacy for transparent, stable policies and transition periods is essential.
# - **Brokers:**
#   Need to stay informed about neighborhood-specific zoning contexts and upcoming bylaw amendments to advise clients accurately on development potential, compliance requirements, and market trends.
# - **Urban Planners and Policy Makers:**
#   Should balance densification objectives with neighborhood preservation and investor confidence through inclusive consultation, data-driven policy adjustments, and clear transition mechanisms.
# - **Builders:**
#   Benefit from enhanced education and compliance support but face increased complexity and potential redesign costs under new regulations.
# ---
# ### **Conclusion**
# Edmonton’s recent zoning bylaw changes, development permit process enhancements, and urban growth policies reflect the city’s efforts to promote sustainable, affordable, and context-sensitive urban densification. However, abrupt policy shifts—particularly the reduction in allowable units per lot and restrictive setback and building depth rules—have generated significant concerns among developers, investors, and residents. These include threats to housing supply, project viability, and investor confidence, as well as challenges in preserving neighborhood character and infrastructure capacity.
# For the commercial real estate industry, these developments underscore the critical need for adaptive strategies, proactive stakeholder engagement, and advocacy for transparent, stable regulatory environments with clear transition provisions. Collaborative efforts among the city, industry, and communities will be essential to achieving balanced growth that supports economic vitality, housing affordability, and neighborhood livability in Edmonton’s evolving urban landscape.

# %% [markdown]
# # Temp 0, changed prompt to make more concise and fact based:

# %% [markdown]
# Recent developments in Edmonton’s zoning bylaws and related policies are creating significant uncertainty and tension within the commercial real estate sector, particularly affecting infill residential and gentle density projects. The 2023 zoning bylaw renewal initially supported densification by allowing up to eight units per lot in multi-unit residential developments, aligning with city goals to reduce sprawl, enhance sustainability, and increase housing near transit. This was broadly welcomed by investors, developers, and brokers.
#
# However, proposed amendments to reduce maximum units per lot from eight to six—or even lower in some zones—along with new building depth limits (e.g., 50% of lot depth) and increased setback requirements, have sparked strong opposition. Developers warn these restrictions threaten project viability by reducing density and building footprints, increasing design complexity, and causing costly delays. Financial impacts include sunk design and consulting costs exceeding $150,000 per lot and construction delays of six to nine months. The abrupt timing of these changes, without grandfathering or transition periods, has eroded trust and risks diverting investment to other markets.
# Setback rules are also under scrutiny. The current uniform 4.5-metre front setback conflicts with existing neighbourhood character, where setbacks often range from 8 to 9 metres. Stakeholders support more context-sensitive, flexible setback standards to better preserve neighbourhood aesthetics. Adjustments to side yard setbacks and allowances for projections aim to improve accessibility and drainage.
#
# To improve transparency and community relations, the city proposes expanding development permit notification requirements to include adjacent property owners before final submission, beyond just demolition permits. The creation of an Infill Liaison Team aims to enhance communication between the city, builders, and communities, addressing complaints and educating new builders to improve compliance and enforcement.
#
# Concerns also focus on the impact of zoning changes on neighborhood character, property rights, and affordable housing stock. Critics argue that high-density infill and elimination of single-family zoning reduce affordability, infringe on property owners’ rights, and negatively affect sunlight, privacy, and landscaping. Calls for progressive planning measures include requiring shadow studies, addressing bulk and architectural compatibility, and adopting flexible design standards inspired by other cities like Calgary. Some community members advocate moratoriums on further densification except for limited housing types and enhanced citizen engagement, including appeal rights on development applications.
#
# City council discussions emphasize the need for balanced, context-sensitive policies that encourage incremental densification—such as permitting up to six units per lot with design features compatible with mature neighbourhoods—while managing infrastructure capacity and community impacts. Data shows most recent infill permits involve row houses with six or more units, highlighting the critical role of unit caps in shaping development patterns. The removal of parking minimums and alignment of growth with transit infrastructure are viewed positively for sustainable urban growth.
#
# Overall, Edmonton’s evolving zoning framework presents both challenges and opportunities for real estate investors, developers, and brokers. Key issues include the financial viability of projects amid changing density limits, the necessity of clear and fair transition policies, balancing densification with neighbourhood preservation, and ensuring meaningful community consultation. The industry calls for more transparent, collaborative, and data-driven policymaking to maintain investor confidence, support housing supply growth, and sustain a healthy commercial real estate market.

# %% [markdown]
# # Added source attribution and changed prompts
#
#         map_prompt = PromptTemplate(
#             template=(
#                 "Summarize the following city council transcript excerpt, focusing ONLY on topics that"
#                 "could be relevant to the commercial real estate industry (zoning, property bylaws,"
#                 "property tax issues, general discussion about real estate or topics relevant to real estate"
#                 "investors, brokers or developers etc.). When stating factual information from the transcript"
#                 "excerpt, include the provided source link in parentheses for attribution.\n\n{text}\n\nSummary:"
#             ),
#             input_variables=["text"],
#         )
#
#         combine_prompt = PromptTemplate(
#             template=(
#                 "Combine the following partial summaries into a single coherent summary. Extract"
#                 "important information that could impact the commercial real estate industry, including zoning"
#                 "and bylaw changes, property tax discussions, general discussion about real estate or topics"
#                 "relevant to real estate investors, brokers or developers, etc. Make the report as concise as"
#                 "possible while using as many facts from the text as you can. Focus on changes that are happening"
#                 "and any arguments that were for or against the changes. Only include information that was directly"
#                 "discussed in the text and include inline source citations (the YouTube links provided in square"
#                 "brackets). :\n\n{text}\n\nFinal Summary:"
#             ),
#             input_variables=["text"],
#         )

# %% [markdown]
# Recent Edmonton city council discussions highlight significant tensions and changes in zoning bylaws that directly affect the commercial real estate industry, particularly developers, investors, and brokers involved in mature neighborhoods and mid-block infill projects. A key amendment reduced the maximum allowable units per lot from eight to six in multi-unit residential developments, prompting strong criticism from developers who cite substantial financial impacts—including lost rental income, increased redesign and holding costs (estimated at $150,000 per plot), and project delays of six to nine months—due to the abrupt implementation and lack of a grandfathering or transition period for applications submitted under previous rules. This has eroded investor confidence and risks deterring future capital investment, potentially exacerbating housing affordability challenges amid Edmonton’s rapid population growth of over 65,000 residents in the past year [https://www.youtube.com/watch?v=-INUkkTyEwY&t=14393s; https://www.youtube.com/watch?v=-INUkkTyEwY&t=15996s; https://www.youtube.com/watch?v=-INUkkTyEwY&t=14030s].
#
# Developers also raised concerns about stricter setback requirements and reduced maximum building lengths, which limit build efficiency and density, threatening project feasibility on shallow or large lots and risking financing viability and job losses. The absence of a clear, well-communicated transition timeline and insufficient consultation with industry professionals and community members were repeatedly criticized, with calls for improved engagement to ensure zoning changes are practical and context-sensitive [https://www.youtube.com/watch?v=-INUkkTyEwY&t=11661s; https://www.youtube.com/watch?v=-INUkkTyEwY&t=4406s; https://www.youtube.com/watch?v=-INUkkTyEwY&t=15575s].
#
# Opponents of the current zoning bylaw 2001 argue it enables “predatory infill” that diminishes sunlight, privacy, and landscaping for existing properties, reducing enjoyment and resale values. They contend these changes infringe on property rights protected under Alberta and Canadian Bills of Rights and call for compensation or legal remedies. The bylaw’s failure to mandate adequate shadow studies or address bulk, size, privacy, and architectural compatibility—especially for buildings over six stories—was noted as a shortcoming compared to stricter standards in cities like Ottawa [[1]](https://www.youtube.com/watch?v=-INUkkTyEwY&t=2109s).
#
# Conversely, some community members and council supporters argue that removing the ÚK zoning bylaw, which allowed up to eight units per lot, promotes densification and reduces urban sprawl without overwhelming infrastructure. Data presented showed that over the past 18 months, 1,145 building permits were issued in mature neighborhoods, with 30% for row houses and 255 permits (22% of all permits) for buildings with seven or more units, underscoring the significant role of larger multi-unit developments in the local market. Council members emphasized that only about 3% of infill permits in 2024 were for seven or eight-unit multiplexes, indicating large-scale infill remains a small portion of overall development [https://www.youtube.com/watch?v=-INUkkTyEwY&t=4635s; https://www.youtube.com/watch?v=-INUkkTyEwY&t=12574s; https://www.youtube.com/watch?v=-INUkkTyEwY&t=4829s].
#
# The city framed the recent zoning bylaw renewal as a success in enabling increased housing density near transit corridors and within established neighborhoods without major new infrastructure costs, aligning with goals to reduce urban sprawl, lower greenhouse gas emissions, and improve fiscal sustainability. Amendments also include removing all parking minimum requirements to enhance neighborhood vibrancy and resilience, and improving development permit notification processes by requiring direct notice to adjacent property owners, increasing transparency and early community engagement [https://www.youtube.com/watch?v=-INUkkTyEwY&t=12950s; https://www.youtube.com/watch?v=-INUkkTyEwY&t=22347s].
#
# To address developer concerns, city staff proposed extending the validity of development permit applications submitted before the public hearing date through January 2024, providing a minimum 12-month adjustment period to preserve approval pipeline priority. This aims to balance housing development momentum with neighborhood expectations and regulatory certainty [https://www.youtube.com/watch?v=-INUkkTyEwY&t=2682s].
#
# However, broader growth strategy concerns remain, including whether residents are adequately informed about trade-offs such as demolition of older single-family homes for higher-density housing, expansion of agricultural greenbelt areas, and the impact of containment policies on housing affordability. These issues underscore ongoing tensions between urban densification goals, zoning regulations, and market impacts critical for real estate stakeholders navigating Edmonton’s evolving landscape [https://www.youtube.com/watch?v=-INUkkTyEwY&t=2682s].
#
# In summary, Edmonton’s evolving zoning landscape presents both challenges and opportunities for commercial real estate investors, developers, and brokers. Key issues include balancing densification with neighborhood preservation, ensuring fair and transparent policy transitions, addressing community concerns through improved engagement, and adopting regulatory flexibility. The outcome of these discussions will significantly influence investment confidence, development feasibility, and the city’s ability to meet housing demand sustainably.

# %% [markdown]
# # "stuff" instead of map_reduce and changed prompts

# %% [markdown]
# # Edmonton Zoning Bylaw Amendments and Impact on Commercial Real Estate
# This report summarizes recent discussions and stakeholder feedback regarding proposed amendments to Edmonton’s zoning bylaw, particularly focusing on changes affecting infill development, multiplex unit caps, and related planning policies. The changes and debates have significant implications for real estate investors, developers, brokers, and the broader commercial real estate market.
# ---
# ## Key Proposed Changes and Context
# - **Reduction of Maximum Units in Multiplexes:**
#   The current zoning bylaw allows up to **eight units** on a single lot (including midblock). The proposed amendment seeks to reduce this cap to **six units**. This change is part of broader efforts to moderate the pace and scale of densification in mature neighbourhoods [[2]](https://www.youtube.com/watch?v=-INUkkTyEwY&t=12574s).
# - **Setbacks and Building Design:**
#   Amendments include adjustments to front and side yard setbacks, building length limits, and restrictions on side yard entrances to better preserve neighbourhood character and privacy. Some stakeholders suggest more nuanced rules, such as differentiating between elevated and ground-level side entrances to allow design flexibility while maintaining privacy [[3]](https://www.youtube.com/watch?v=-INUkkTyEwY&t=15168s), [[7]](https://www.youtube.com/watch?v=-INUkkTyEwY&t=11661s).
# - **Notification and Enforcement Enhancements:**
#   The city plans to improve notification processes by informing adjacent neighbours earlier in the development permit process and increase enforcement resources to handle rising complaints related to infill development [[8]](https://www.youtube.com/watch?v=-INUkkTyEwY&t=22525s).
# ---
# ## Stakeholder Perspectives
# ### Concerns and Opposition
# - **Impact on Property Rights and Values:**
#   Residents and investors express that the zoning changes, especially the reduction from eight to six units, undermine property rights and cause financial harm. Many have invested based on the existing bylaw and face significant redesign costs, delays, and loss of property value without compensation or a transition period [[1]](https://www.youtube.com/watch?v=-INUkkTyEwY&t=2109s), [[6]](https://www.youtube.com/watch?v=-INUkkTyEwY&t=14393s), [[9]](https://www.youtube.com/watch?v=-INUkkTyEwY&t=15793s), [[10]](https://www.youtube.com/watch?v=-INUkkTyEwY&t=15575s).
# - **Lack of Consultation and Transition:**
#   Many speakers criticize the perceived lack of meaningful citizen consultation and the abrupt nature of the proposed changes. They call for a moratorium on new developments beyond single lots and duplexes until a more inclusive process is established. A clear, reasonable transition period is urged to protect ongoing projects and maintain trust between the city and developers [[1]](https://www.youtube.com/watch?v=-INUkkTyEwY&t=2109s), [[4]](https://www.youtube.com/watch?v=-INUkkTyEwY&t=4635s), [[6]](https://www.youtube.com/watch?v=-INUkkTyEwY&t=14393s), [[9]](https://www.youtube.com/watch?v=-INUkkTyEwY&t=15793s).
# - **Questioning the “Magic Number” Six:**
#   The rationale for choosing six units as the new cap is unclear and seen as arbitrary by some. Alternatives such as four, five, or seven units were considered, but the decision appears driven by committee direction rather than data or community input [[2]](https://www.youtube.com/watch?v=-INUkkTyEwY&t=12574s).
# - **Neighbourhood Character and Infrastructure Concerns:**
#   Some residents argue that rapid densification harms neighbourhood character, reduces sunlight, privacy, and quiet enjoyment of properties, and strains infrastructure. They call for more progressive planning tools such as shadow studies, bulk and massing controls, and better design standards to protect mature neighbourhoods [[1]](https://www.youtube.com/watch?v=-INUkkTyEwY&t=2109s), [[5]](https://www.youtube.com/watch?v=-INUkkTyEwY&t=2882s).
# - **Affordable Housing Stock Erosion:**
#   There is concern that predatory infill development is reducing affordable housing options by replacing single-family homes with high-density rental properties, which may not provide affordable homeownership opportunities [[1]](https://www.youtube.com/watch?v=-INUkkTyEwY&t=2109s), [[6]](https://www.youtube.com/watch?v=-INUkkTyEwY&t=12950s).
# ---
# ### Support and Defense of the Bylaw Renewal
# - **Success of the Current Bylaw:**
#   Some stakeholders argue the zoning bylaw renewal has been successful in increasing housing supply, densifying mature neighbourhoods, and reducing urban sprawl without major infrastructure costs. They note that only a small percentage (~3%) of infill permits are for seven or eight-unit buildings, suggesting concerns are disproportionate [[2]](https://www.youtube.com/watch?v=-INUkkTyEwY&t=4829s).
# - **Neighbourhood Character is Socially Constructed:**
#   Supporters contend that neighbourhood character is defined by the community, not by building height or density, and that densification supports environmental and fiscal sustainability goals [[2]](https://www.youtube.com/watch?v=-INUkkTyEwY&t=4829s).
# - **Need for Gentle Densification and Design Improvements:**
#   While supporting densification, some advocate for better design standards, waste management, and infrastructure improvements rather than unit caps. They caution against “wrong fixes” that limit needed housing supply [[5]](https://www.youtube.com/watch?v=-INUkkTyEwY&t=15996s), [[6]](https://www.youtube.com/watch?v=-INUkkTyEwY&t=13842s).
# ---
# ## Commercial Real Estate Implications
# - **Investment Risk and Uncertainty:**
#   The abrupt zoning changes and lack of transition periods create financial risks for developers and investors, potentially reducing confidence in Edmonton’s real estate market. This may lead to capital flight or reduced investment in infill projects, especially those relying on financing models predicated on eight-unit developments [[6]](https://www.youtube.com/watch?v=-INUkkTyEwY&t=14393s), [[9]](https://www.youtube.com/watch?v=-INUkkTyEwY&t=15793s).
# - **Potential Slowdown in Infill Development:**
#   The reduction in allowable units and increased design restrictions could slow the pace of infill development, impacting housing supply and rental market dynamics in mature neighbourhoods.
# - **Need for Clear Policy and Engagement:**
#   Developers and investors call for clearer, data-driven policies with robust community engagement to balance growth, affordability, and neighbourhood character. Improved notification and enforcement processes may help mitigate conflicts and improve project outcomes [[7]](https://www.youtube.com/watch?v=-INUkkTyEwY&t=11661s), [[8]](https://www.youtube.com/watch?v=-INUkkTyEwY&t=22525s).
# ---
# ## Summary and Recommendations
# - The proposed zoning bylaw amendments, especially the reduction of multiplex units from eight to six, have sparked significant debate with strong arguments both for and against.
# - Key concerns include the financial impact on current investors, lack of transition periods, unclear rationale for unit caps, and effects on neighbourhood character and infrastructure.
# - Supporters emphasize the success of densification efforts in curbing sprawl and meeting housing needs, advocating for design and enforcement improvements rather than restrictive caps.
# - For commercial real estate stakeholders, these changes introduce uncertainty and risk, underscoring the need for transparent, consultative policy processes and fair transition mechanisms.
# - The city’s approach to notification and enforcement is improving but requires ongoing monitoring to balance development with community interests.
# ---
# **Sources:**
# [1] Public comments on predatory infill and property rights [[1]](https://www.youtube.com/watch?v=-INUkkTyEwY&t=2109s)
# [2] Discussion on unit caps and infill pace [[2]](https://www.youtube.com/watch?v=-INUkkTyEwY&t=12574s)
# [3] Recommendations on side yard entrances and setbacks [[3]](https://www.youtube.com/watch?v=-INUkkTyEwY&t=15168s)
# [4] Calls for moratorium and citizen engagement [[4]](https://www.youtube.com/watch?v=-INUkkTyEwY&t=4635s)
# [5] Critique of monolithic development strategy [[5]](https://www.youtube.com/watch?v=-INUkkTyEwY&t=2882s)
# [6] Investor concerns on financial impact and transition [[6]](https://www.youtube.com/watch?v=-INUkkTyEwY&t=14393s)
# [7] Infill liaison team and notification improvements [[7]](https://www.youtube.com/watch?v=-INUkkTyEwY&t=11661s)
# [8] Enforcement resources and complaint coordination [[8]](https://www.youtube.com/watch?v=-INUkkTyEwY&t=22525s)
# [9] Investor testimony on project delays and losses [[9]](https://www.youtube.com/watch?v=-INUkkTyEwY&t=15793s)
# [10] Investor concerns on sudden policy changes [[10]](https://www.youtube.com/watch?v=-INUkkTyEwY&t=15575s)
